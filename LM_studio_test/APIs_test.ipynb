# %% [markdown]
# # LLama2 prompt engineering

# %%
def call_llama(event, gender):
    client = OpenAI(base_url="http://localhost:1234/v1", api_key="not-needed")
    
    completion = client.chat.completions.create(
      model="local-model", # this field is currently unused
      messages=[
        {"role": "system", "content": "Below is an instruction that describes a task. Write a response that appropriately completes the request."},
        {"role": "user", "content": f'Suggest some attires for {event} for {gender}. For each apparel in the outfit give its color. Each outfit on a new line. Suggest less than 5 outfits. Do not use special characters like "-" and "#" in the response generated by you. Response:less Ten words reply for each outfit:' }
      ],
      temperature=0.5
    )

    return list(completion.choices[0].message)[0][1]

# %%
def clean_tokens(response):
    
    response = response.split('.')
    response = [item.split(" - ") for item in response]
    response = [item for sublist in response for item in sublist]
    
    response = [txt for txt in response if len(txt) > 28]

    for indx, apparel in enumerate(response):
        apparel = apparel.replace("with",",").replace("and",",").replace(" ' ","")
        apparel = apparel.split(',')
        apparel = [txt.strip() for txt in apparel]
    
        response[indx] = apparel

    return response

# %%
res = call_llama('SDE job interview','Women')
print(res)

print('\n')
print('\n')
print('\n')

print(clean_tokens(res))
# Out:
# 1. Black Pantsuit with White Blouse - Simple yet elegant, perfect for a professional setting.
# 2. Navy Blue Blazer with White Shirt - Crisp and polished, exudes confidence and poise.
# 3. Grey Skinny Jeans with White Top - Modern and stylish, great for a casual interview setting.
# 4. Beige Suit with Navy Blue Dress Shirt - Timeless and versatile, ideal for a formal interview.
# 5. Red Dress with Black Heels - A bold and eye-catching outfit that commands attention.
#
#
#
#
#
#
# [['Black Pantsuit', 'White Blouse'], ['Simple yet elegant', 'perfect for a professional setting'], ['Navy Blue Blazer', 'White Shirt'], ['Crisp', 'polished', 'exudes confidence', 'poise'], ['Grey Skinny Jeans', 'White Top'], ['Modern', 'stylish', 'great for a casual interview setting'], ['Beige Suit', 'Navy Blue Dress Shirt'], ['Timeless', 'versatile', 'ideal for a formal interview'], ['A bold', 'eye-catching outfit that comm', 's attention']]

# %%
res = call_llama('SDE job interview','Men')
print(res)

print('\n')
print('\n')
print('\n')

print(clean_tokens(res))
# Out:
# 1. Business suit with white shirt and black tie - Black
# 2. Charcoal gray three-piece suit - Gray
# 3. Navy blue blazer with crisp white shirt and khaki pants - Blue
# 4. Dark brown dress shoes with navy blue trousers - Brown
# 5. Light blue dress shirt with charcoal gray suit - Gray
#
#
#
#
#
#
# [['Business suit', 'white shirt', 'black tie'], ['Charcoal gray three-piece suit'], ['Navy blue blazer', 'crisp white shirt', 'khaki pants'], ['Dark brown dress shoes', 'navy blue trousers'], ['Light blue dress shirt', 'charcoal gray suit']]

# %%
res = call_llama('date night','Men')
print(res)

print('\n')


print(clean_tokens(res))
# Out:
# For a date night, here are some suggested attires for men:
# 1. A black suit with a crisp white shirt and a red tie.
# 2. A navy blue blazer with khaki pants and a light blue button-down shirt.
# 3. A gray dress shirt with charcoal pants and a brown leather belt.
# 4. A beige linen suit with a white dress shirt and tan loafers.
# 5. A brown tweed jacket with cream-colored chinos and a burgundy tie.
#
#
# [['For a date night', 'here are some suggested attires for men:\n1'], ['A black suit', 'a crisp white shirt', 'a red tie'], ['A navy blue blazer', 'khaki pants', 'a light blue button-down shirt'], ['A gray dress shirt', 'charcoal pants', 'a brown leather belt'], ['A beige linen suit', 'a white dress shirt', 'tan loafers'], ['A brown tweed jacket', 'cream-colored chinos', 'a burgundy tie']]

# %%
res = call_llama('date night','Women')
print(res)

print('\n')

print(clean_tokens(res))
# Out:
# 1. Black dress with silver heels - Glamorous and sophisticated.
# 2. Navy blue blazer with white pants - Elegant and professional.
# 3. Red skirt with black tights - Seductive and feminine.
# 4. Brown suede jacket with jeans - Rustic and chic.
# 5. White blouse with red scarf - Classic and romantic.
#
#
# [['Black dress', 'silver heels'], ['Navy blue blazer', 'white pants'], ['Brown suede jacket', 'jeans']]

# %%
res = call_llama('Wedding Ceremony','Women')
print(res)

print('\n')

print(clean_tokens(res))
# Out:
# 1. Pastel pink chiffon lehenga with golden border and embroidery, paired with matching heels and jewelry.
# 2. Soft ivory lace gown with floral pattern and delicate beading, paired with neutral sandals and simple earrings.
# 3. Rich hunter green velvet salwar kameez with intricate embroidery and gold work, paired with statement jewelry and peep-toe heels.
# 4. Elegant champagne silk sari with intricate border and pallu, paired with matching blouse and jewelry.
# 5. Whimsical lavender tulle dress with lace overlay and delicate embroidery, paired with ballet flats and a simple necklace.
#
#
# [['Pastel pink chiffon lehenga', 'golden border', 'embroidery', 'paired', 'matching heels', 'jewelry'], ['Soft ivory lace gown', 'floral pattern', 'delicate beading', 'paired', 'neutral s', 'als', 'simple earrings'], ['Rich hunter green velvet salwar kameez', 'intricate embroidery', 'gold work', 'paired', 'statement jewelry', 'peep-toe heels'], ['Elegant champagne silk sari', 'intricate border', 'pallu', 'paired', 'matching blouse', 'jewelry'], ['Whimsical lavender tulle dress', 'lace overlay', 'delicate embroidery', 'paired', 'ballet flats', 'a simple necklace']]

# %%
res = call_llama('Wedding Ceremony','Men')
print(res)

print('\n')

print(clean_tokens(res))
# Out:
# Sure, here are some suggestions for men's attire for a wedding ceremony:
# 1. Suit and tie in navy blue
# 2. Tuxedo in black
# 3. Blazer and dress pants in charcoal gray
# 4. Dress shirt in white
# 5. Khaki pants and button-down shirt in olive green
#
#
# [['Sure', "here are some suggestions for men's attire for a wedding ceremony:\n1"], ['Blazer', 'dress pants in charcoal gray\n4'], ['Khaki pants', 'button-down shirt in olive green']]

# %%
res = call_llama('gym','Men')
print(res)

print('\n')

print(clean_tokens(res))
# Out:
# 1. Black T-shirt and blue shorts for a casual gym look.
# 2. White tank top and red sports bra for a bold statement.
# 3. Grey sweatpants and yellow hoodie for a cozy workout set.
# 4. Green athletic shoes and white socks for a fresh and sporty vibe.
# 5. Navy blue sports jacket and white pants for a stylish and functional outfit.
#
#
# [['Black T-shirt', 'blue shorts for a casual gym look'], ['White tank top', 'red sports bra for a bold statement'], ['Grey sweatpants', 'yellow hoodie for a cozy workout set'], ['Green athletic shoes', 'white socks for a fresh', 'sporty vibe'], ['Navy blue sports jacket', 'white pants for a stylish', 'functional outfit']]

# %%
res = call_llama('gym','Women')
print(res)

print('\n')

print(clean_tokens(res))
# Out:
# Sure, here are some gym attire suggestions for women along with their colors:
# 1. Black sports bra and leggings (color: black)
# 2. Navy blue tank top and gray sweatpants (color: navy blue and gray)
# 3. Neon pink yoga mat and matching socks (color: neon pink)
# 4. White athletic shoes with red laces (color: white)
# 5. Green and yellow sports bra and shorts (color: green and yellow)
#
#
# [['Sure', 'here are some gym attire suggestions for women along', 'their colors:\n1'], ['Black sports bra', 'leggings (color: black)\n2'], ['Navy blue tank top', 'gray sweatpants (color: navy blue', 'gray)\n3'], ['Neon pink yoga mat', 'matching socks (color: neon pink)\n4'], ['White athletic shoes', 'red laces (color: white)\n5'], ['Green', 'yellow sports bra', 'shorts (color: green', 'yellow)']]
